# %%
import pandas as pd
from os import listdir
from os.path import isfile, join

# Read all results from txt files


aco_path = "./raw_files/ACO/"
aco_files = [f for f in listdir(aco_path) if isfile(join(aco_path, f))]

ga_path = "./raw_files/GA/"
ga_files = [f for f in listdir(ga_path) if isfile(join(ga_path, f))]

pso_path = "./raw_files/PSO/"
pso_files = [f for f in listdir(pso_path) if isfile(join(pso_path, f))]





# Ant Colony Optimization - Data Frame
column_names = ["Data-set", "Size", "Algorithm", "Support", "Run-time", "Memory", "Pattern-count", "Max-iteration", "Iterations", "E-factor"]
df_aco = pd.DataFrame(columns = column_names)

for file in aco_files:
    f_path = join(aco_path,file)
    # res = pd.read_csv(f_path, sep = ': ', header=None, engine='python', nrows=10)
    res = pd.read_csv(f_path, names=["A","B","C"], sep = ':', header=None, engine='python')
    run = float(res['B'][0][0:6]) # run-time
    mem = float(res['B'][1][0:5]) # memory
    alg = res['B'][2] # algorithm
    att = int(res['B'][3]) # number of attributes in the data set
    size = int(res['B'][4])  # data set size

    evp = float(res['B'][5]) # evaporation factor

    sup = float(res['B'][6]) # minimum support
    pat = float(res['B'][8]) # patterns
    mit = int(res['B'][9]) # maximum iteraction count
    its = res.loc[res['B'] == ' Best Cost']['C'].values # iterations
    
    if att == 98:
        col = "C2K"
    elif att == 10:
        col = "B & C"
    elif att == 9:
        col = "UCI"
    elif att == 21:
        col = "Buoys"
    else:
        col = ""
                    
    df_aco = df_aco.append({"Data-set": col, "Size": size, "Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Pattern-count":pat, "Max-iteration":mit, "Iterations":its, "E-factor": evp}, ignore_index=True)


    
    
# -------------------------------------------------------------------------------------
# Genetic Algorithm - Data Frame
column_names = ["Data-set", "Size", "Algorithm", "Support", "Run-time", "Memory", "Pattern-count", "Max-iteration", "Iterations", "N-pop", "PC"]
df_ga = pd.DataFrame(columns = column_names)

for file in ga_files:
    f_path = join(ga_path,file)
    res = pd.read_csv(f_path, names=["A","B","C"], sep = ':', header=None, engine='python')
    run = float(res['B'][0][0:6]) # run-time
    mem = float(res['B'][1][0:5]) # memory
    alg = res['B'][2] # algorithm
    att = int(res['B'][3]) # number of attributes in the data set
    size = int(res['B'][4])  # data set size

    pop = float(res['B'][5]) # population size
    pc = float(res['B'][6]) # population size


    sup = float(res['B'][7]) # minimum support
    pat = float(res['B'][9]) # patterns
    mit = int(res['B'][10]) # maximum iteraction count
    its = res.loc[res['B'] == ' Best Cost']['C'].values # iterations
    
    if att == 98:
        col = "C2K"
    elif att == 10:
        col = "B & C"
    elif att == 9:
        col = "UCI"
    elif att == 21:
        col = "Buoys"
    else:
        col = ""
        
    df_ga = df_ga.append({"Data-set": col, "Size": size, "Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Pattern-count":pat, "Max-iteration":mit, "Iterations":its, "N-pop": pop, "PC": pc}, ignore_index=True)



# -------------------------------------------------------------------------------------
# Particle Swarm Optimization - Data Frame
column_names = ["Data-set", "Size", "Algorithm", "Support", "Run-time", "Memory", "Pattern-count", "Max-iteration", "Iterations", "N-particle", "Velocity", "C1", "C2"]
df_pso = pd.DataFrame(columns = column_names)

for file in pso_files:
    f_path = join(pso_path,file)
    res = pd.read_csv(f_path, names=["A","B","C"], sep = ':', header=None, engine='python')
    run = float(res['B'][0][0:6]) # run-time
    mem = float(res['B'][1][0:5]) # memory
    alg = res['B'][2] # algorithm
    att = int(res['B'][3]) # number of attributes in the data set
    size = int(res['B'][4])  # data set size

    vel = float(res['B'][5]) # velocity
    c1 = float(res['B'][6]) # personal coefficient
    c2 = float(res['B'][7]) # global coefficient
    npat = float(res['B'][8]) # particle count

    sup = float(res['B'][9]) # minimum support
    pat = float(res['B'][11]) # patterns
    mit = int(res['B'][12]) # maximum iteraction count
    its = res.loc[res['B'] == ' Best Position']['C'].values # iterations
    
    if att == 98:
        col = "C2K"
    elif att == 10:
        col = "B & C"
    elif att == 9:
        col = "UCI"
    elif att == 21:
        col = "Buoys"
    else:
        col = ""
        
    df_pso = df_pso.append({"Data-set": col, "Size": size, "Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Pattern-count":pat, "Max-iteration":mit, "Iterations":its, "N-particle": npat, "Velocity": vel, "C1": c1, "C2": c2}, ignore_index=True)

# %%
df_aco1 = df_aco[['Data-set', 'Algorithm', 'Pattern-count', 'Run-time', 'Memory', 'E-factor']]
df_aco1 = df_aco1.groupby(["Algorithm", "E-factor", "Data-set"]).describe(percentiles=[])
df_aco1
# Out:
#                                      Pattern-count                             \
#                                              count       mean       std   min
# Algorithm          E-factor Data-set
#  ACO-GRAANK (v2.0) 0.1      B & C              3.0  21.666667  1.527525  20.0
#                             Buoys              3.0  40.333333  5.131601  36.0
#                             C2K                3.0  33.333333  1.154701  32.0
#                             UCI                3.0   4.333333  2.516611   2.0
#                    0.3      B & C              3.0  18.000000  3.605551  14.0
#                             Buoys              3.0  38.666667  4.725816  35.0
#                             C2K                3.0  27.333333  3.785939  23.0
#                             UCI                3.0   5.000000  1.732051   4.0
#                    0.5      B & C              3.0  16.333333  2.886751  13.0
#                             Buoys              3.0  37.666667  5.131601  32.0
#                             C2K                3.0  22.000000  3.605551  18.0
#                             UCI                3.0   4.333333  0.577350   4.0
#                    0.9      B & C              3.0  13.666667  5.033223   9.0
#                             Buoys              3.0  28.000000  5.291503  24.0
#                             C2K                3.0  20.333333  4.509250  16.0
#                             UCI                3.0   3.333333  0.577350   3.0
#
#                                                  Run-time              \
#                                        50%   max    count        mean
# Algorithm          E-factor Data-set
#  ACO-GRAANK (v2.0) 0.1      B & C     22.0  23.0      3.0    0.944000
#                             Buoys     39.0  46.0      3.0   39.540000
#                             C2K       34.0  34.0      3.0   42.550000
#                             UCI        4.0   7.0      3.0  167.900000
#                    0.3      B & C     19.0  21.0      3.0    0.684667
#                             Buoys     37.0  44.0      3.0   33.550000
#                             C2K       29.0  30.0      3.0   33.486667
#                             UCI        4.0   7.0      3.0  110.133333
#                    0.5      B & C     18.0  18.0      3.0    0.372000
#                             Buoys     39.0  42.0      3.0   29.943333
#                             C2K       23.0  25.0      3.0   29.890000
#                             UCI        4.0   5.0      3.0   71.780000
#                    0.9      B & C     13.0  19.0      3.0    0.211667
#                             Buoys     26.0  34.0      3.0   23.586667
#                             C2K       20.0  25.0      3.0   21.826667
#                             UCI        3.0   4.0      3.0   60.590000
#
#                                                                             \
#                                             std      min      50%      max
# Algorithm          E-factor Data-set
#  ACO-GRAANK (v2.0) 0.1      B & C      0.056956    0.894    0.932    1.006
#                             Buoys      2.798982   36.360   40.630   41.630
#                             C2K        3.963269   39.400   41.250   47.000
#                             UCI       32.012029  134.800  170.200  198.700
#                    0.3      B & C      0.216019    0.467    0.688    0.899
#                             Buoys      4.994887   27.880   35.470   37.300
#                             C2K        2.400174   30.770   34.370   35.320
#                             UCI        5.442732  106.000  108.100  116.300
#                    0.5      B & C      0.052115    0.338    0.346    0.432
#                             Buoys      2.462445   27.720   29.520   32.590
#                             C2K        2.623033   28.180   28.580   32.910
#                             UCI       12.278840   57.830   76.560   80.950
#                    0.9      B & C      0.068632    0.137    0.226    0.272
#                             Buoys      5.441914   20.380   20.510   29.870
#                             C2K        2.262174   20.200   20.870   24.410
#                             UCI        6.112054   56.450   57.710   67.610
#
#                                      Memory                                \
#                                       count        mean        std    min
# Algorithm          E-factor Data-set
#  ACO-GRAANK (v2.0) 0.1      B & C       3.0  128.333333   2.516611  126.0
#                             Buoys       3.0  198.000000   7.000000  190.0
#                             C2K         3.0  202.000000   0.000000  202.0
#                             UCI         3.0  145.333333   8.020806  137.0
#                    0.3      B & C       3.0  122.333333   8.020806  114.0
#                             Buoys       3.0  186.333333   7.505553  179.0
#                             C2K         3.0  200.333333   1.527525  199.0
#                             UCI         3.0  133.000000   1.732051  132.0
#                    0.5      B & C       3.0  115.000000   3.000000  112.0
#                             Buoys       3.0  184.000000   7.810250  175.0
#                             C2K         3.0  199.666667   0.577350  199.0
#                             UCI         3.0  121.666667   2.886751  120.0
#                    0.9      B & C       3.0  107.066667   7.100235   99.2
#                             Buoys       3.0  162.666667  10.969655  154.0
#                             C2K         3.0  199.333333   0.577350  199.0
#                             UCI         3.0  113.000000   1.000000  112.0
#
#
#                                         50%    max
# Algorithm          E-factor Data-set
#  ACO-GRAANK (v2.0) 0.1      B & C     128.0  131.0
#                             Buoys     201.0  203.0
#                             C2K       202.0  202.0
#                             UCI       146.0  153.0
#                    0.3      B & C     123.0  130.0
#                             Buoys     186.0  194.0
#                             C2K       200.0  202.0
#                             UCI       132.0  135.0
#                    0.5      B & C     115.0  118.0
#                             Buoys     188.0  189.0
#                             C2K       200.0  200.0
#                             UCI       120.0  125.0
#                    0.9      B & C     109.0  113.0
#                             Buoys     159.0  175.0
#                             C2K       199.0  200.0
#                             UCI       113.0  114.0

# %%
df_ga1 = df_ga[['Data-set', 'Algorithm', 'Pattern-count', 'Run-time', 'Memory', 'N-pop', 'PC']]
df_ga1 = df_ga1.groupby(["Algorithm", "N-pop", "PC", "Data-set"]).describe(percentiles=[])
df_ga1
# Out:
#                                      Pattern-count                           \
#                                              count      mean       std  min
# Algorithm         N-pop PC  Data-set
#  GA-GRAANK (v1.0) 5.0   0.5 B & C              3.0  4.000000  3.000000  1.0
#                             Buoys              3.0  2.333333  0.577350  2.0
#                             C2K                3.0  2.000000  1.000000  1.0
#                             UCI                3.0  1.000000  0.000000  1.0
#                         0.9 B & C              3.0  2.666667  0.577350  2.0
#                             Buoys              3.0  2.333333  1.154701  1.0
#                             C2K                3.0  1.666667  0.577350  1.0
#                             UCI                3.0  1.333333  0.577350  1.0
#
#                                                Run-time               \
#                                       50%  max    count         mean
# Algorithm         N-pop PC  Data-set
#  GA-GRAANK (v1.0) 5.0   0.5 B & C     4.0  7.0      3.0     0.503333
#                             Buoys     2.0  3.0      3.0   299.633333
#                             C2K       2.0  3.0      3.0   460.533333
#                             UCI       1.0  1.0      3.0   960.433333
#                         0.9 B & C     3.0  3.0      3.0     0.769000
#                             Buoys     3.0  3.0      3.0   555.633333
#                             C2K       2.0  2.0      3.0   804.000000
#                             UCI       1.0  2.0      3.0  1940.000000
#
#                                                                       \
#                                              std       min       50%
# Algorithm         N-pop PC  Data-set
#  GA-GRAANK (v1.0) 5.0   0.5 B & C       0.011015     0.496     0.498
#                             Buoys      30.111515   279.100   285.600
#                             C2K        61.926516   402.600   453.200
#                             UCI       236.911256   722.200   963.100
#                         0.9 B & C       0.053675     0.713     0.774
#                             Buoys     120.561865   418.600   602.900
#                             C2K        53.160512   746.200   815.000
#                             UCI       278.748991  1645.000  1976.000
#
#                                                Memory                        \
#                                            max  count        mean       std
# Algorithm         N-pop PC  Data-set
#  GA-GRAANK (v1.0) 5.0   0.5 B & C        0.516    3.0   97.833333  3.150132
#                             Buoys      334.200    3.0  115.333333  2.516611
#                             C2K        525.800    3.0  124.333333  0.577350
#                             UCI       1196.000    3.0  104.333333  1.154701
#                         0.9 B & C        0.820    3.0   97.100000  1.058301
#                             Buoys      645.400    3.0  116.666667  2.516611
#                             C2K        850.800    3.0  126.000000  1.000000
#                             UCI       2199.000    3.0  106.666667  1.154701
#
#
#                                         min    50%    max
# Algorithm         N-pop PC  Data-set
#  GA-GRAANK (v1.0) 5.0   0.5 B & C      94.7   97.8  101.0
#                             Buoys     113.0  115.0  118.0
#                             C2K       124.0  124.0  125.0
#                             UCI       103.0  105.0  105.0
#                         0.9 B & C      95.9   97.5   97.9
#                             Buoys     114.0  117.0  119.0
#                             C2K       125.0  126.0  127.0
#                             UCI       106.0  106.0  108.0

# %%
df_pso1 = df_pso[['Data-set', 'Algorithm', 'Pattern-count', 'Run-time', 'Memory', 'N-particle', 'C1', 'C2']]
df_pso1 = df_pso1.groupby(["Algorithm", "N-particle", "C1", "C2", "Data-set"]).describe(percentiles=[])
df_pso1
# Out:
#                                                Pattern-count            \
#                                                        count      mean
# Algorithm          N-particle C1  C2  Data-set
#  PSO-GRAANK (v1.0) 5.0        0.5 0.1 B & C              3.0  1.000000
#                                       Buoys              3.0  1.000000
#                                       C2K                3.0  1.666667
#                                       UCI                3.0  1.000000
#                                   0.3 B & C              3.0  1.666667
#                                       Buoys              3.0  1.333333
#                                       C2K                3.0  1.000000
#                                       UCI                3.0  1.000000
#                                   0.5 B & C              3.0  2.000000
#                                       Buoys              3.0  1.333333
#                                       C2K                3.0  1.333333
#                                       UCI                3.0  1.000000
#                                   0.9 B & C              3.0  1.333333
#                                       Buoys              3.0  1.333333
#                                       C2K                3.0  1.333333
#                                       UCI                3.0  1.000000
#
#                                                                         \
#                                                     std  min  50%  max
# Algorithm          N-particle C1  C2  Data-set
#  PSO-GRAANK (v1.0) 5.0        0.5 0.1 B & C     0.00000  1.0  1.0  1.0
#                                       Buoys     0.00000  1.0  1.0  1.0
#                                       C2K       0.57735  1.0  2.0  2.0
#                                       UCI       0.00000  1.0  1.0  1.0
#                                   0.3 B & C     0.57735  1.0  2.0  2.0
#                                       Buoys     0.57735  1.0  1.0  2.0
#                                       C2K       0.00000  1.0  1.0  1.0
#                                       UCI       0.00000  1.0  1.0  1.0
#                                   0.5 B & C     0.00000  2.0  2.0  2.0
#                                       Buoys     0.57735  1.0  1.0  2.0
#                                       C2K       0.57735  1.0  1.0  2.0
#                                       UCI       0.00000  1.0  1.0  1.0
#                                   0.9 B & C     0.57735  1.0  1.0  2.0
#                                       Buoys     0.57735  1.0  1.0  2.0
#                                       C2K       0.57735  1.0  1.0  2.0
#                                       UCI       0.00000  1.0  1.0  1.0
#
#                                                Run-time               \
#                                                   count         mean
# Algorithm          N-particle C1  C2  Data-set
#  PSO-GRAANK (v1.0) 5.0        0.5 0.1 B & C         3.0     0.745000
#                                       Buoys         3.0   465.700000
#                                       C2K           3.0   685.866667
#                                       UCI           3.0  1544.700000
#                                   0.3 B & C         3.0     0.493667
#                                       Buoys         3.0   498.300000
#                                       C2K           3.0   793.333333
#                                       UCI           3.0  2228.000000
#                                   0.5 B & C         3.0     0.490000
#                                       Buoys         3.0   336.900000
#                                       C2K           3.0   763.366667
#                                       UCI           3.0  2205.333333
#                                   0.9 B & C         3.0     0.466667
#                                       Buoys         3.0   645.433333
#                                       C2K           3.0   775.266667
#                                       UCI           3.0  2358.333333
#
#                                                                        \
#                                                         std       min
# Algorithm          N-particle C1  C2  Data-set
#  PSO-GRAANK (v1.0) 5.0        0.5 0.1 B & C        0.169284     0.594
#                                       Buoys      140.267993   331.200
#                                       C2K        194.465687   513.900
#                                       UCI       1025.542573   617.100
#                                   0.3 B & C        0.182544     0.294
#                                       Buoys      124.576362   384.500
#                                       C2K         71.666194   713.100
#                                       UCI        645.137970  1687.000
#                                   0.5 B & C        0.090863     0.426
#                                       Buoys      244.942422   157.200
#                                       C2K        198.262814   592.600
#                                       UCI        554.856138  1784.000
#                                   0.9 B & C        0.055103     0.419
#                                       Buoys      206.894208   465.500
#                                       C2K         34.669343   736.500
#                                       UCI        999.474529  1329.000
#
#                                                                    Memory  \
#                                                      50%       max  count
# Algorithm          N-particle C1  C2  Data-set
#  PSO-GRAANK (v1.0) 5.0        0.5 0.1 B & C        0.713     0.928    3.0
#                                       Buoys      454.800   611.100    3.0
#                                       C2K        646.800   896.900    3.0
#                                       UCI       1371.000  2646.000    3.0
#                                   0.3 B & C        0.535     0.652    3.0
#                                       Buoys      479.000   631.400    3.0
#                                       C2K        815.900   851.000    3.0
#                                       UCI       2055.000  2942.000    3.0
#                                   0.5 B & C        0.450     0.594    3.0
#                                       Buoys      237.600   615.900    3.0
#                                       C2K        716.700   980.800    3.0
#                                       UCI       1998.000  2834.000    3.0
#                                   0.9 B & C        0.454     0.527    3.0
#                                       Buoys      599.300   871.500    3.0
#                                       C2K        786.000   803.300    3.0
#                                       UCI       2421.000  3325.000    3.0
#
#                                                                              \
#                                                       mean       std    min
# Algorithm          N-particle C1  C2  Data-set
#  PSO-GRAANK (v1.0) 5.0        0.5 0.1 B & C      84.833333  1.006645   83.9
#                                       Buoys     102.666667  0.577350  102.0
#                                       C2K       113.666667  0.577350  113.0
#                                       UCI        94.966667  2.182506   92.6
#                                   0.3 B & C      84.466667  1.201388   83.3
#                                       Buoys     102.000000  0.000000  102.0
#                                       C2K       113.000000  1.000000  112.0
#                                       UCI        96.933333  0.321455   96.7
#                                   0.5 B & C      84.933333  0.378594   84.5
#                                       Buoys     102.666667  0.577350  102.0
#                                       C2K       114.333333  1.527525  113.0
#                                       UCI        95.666667  1.101514   94.6
#                                   0.9 B & C      83.933333  0.602771   83.3
#                                       Buoys     103.333333  1.154701  102.0
#                                       C2K       114.333333  1.527525  113.0
#                                       UCI        95.433333  2.345918   92.8
#
#
#                                                   50%    max
# Algorithm          N-particle C1  C2  Data-set
#  PSO-GRAANK (v1.0) 5.0        0.5 0.1 B & C      84.7   85.9
#                                       Buoys     103.0  103.0
#                                       C2K       114.0  114.0
#                                       UCI        95.4   96.9
#                                   0.3 B & C      84.4   85.7
#                                       Buoys     102.0  102.0
#                                       C2K       113.0  114.0
#                                       UCI        96.8   97.3
#                                   0.5 B & C      85.1   85.2
#                                       Buoys     103.0  103.0
#                                       C2K       114.0  116.0
#                                       UCI        95.6   96.8
#                                   0.9 B & C      84.0   84.5
#                                       Buoys     104.0  104.0
#                                       C2K       114.0  116.0
#                                       UCI        96.2   97.3

# %%
# Combining the results
frames = [df_aco, df_ga, df_pso]
df_res = pd.concat(frames)

# Only include these columns
df_res2 = df_res[['Data-set', 'Algorithm', 'Pattern-count', 'Run-time', 'Memory']]  #, 'E-factor', 'N-pop', 'N-particle', 'C1', 'C2']]

df = df_res2.groupby(['Algorithm', 'Data-set'])#.describe(percentiles=[])
df2 = pd.concat([df.min(), df.mean(), df.max(), df.std()], keys=['min', 'mean', 'max', 'std'], axis=1)
# df2.filter(like="Run-time")
df2.columns = df2.columns.swaplevel(0, 1)
df2.sort_index(axis=1, level=0, inplace=True, ascending=False)
df2.round(3)
# Out:
#                             Run-time                               \
#                                  std      min      mean       max
# Algorithm          Data-set
#  ACO-GRAANK (v2.0) B & C       0.312    0.137     0.553     1.006
#                    Buoys       6.995   20.380    31.655    41.630
#                    C2K         8.153   20.200    31.938    47.000
#                    UCI        46.311   56.450   102.601   198.700
#  GA-GRAANK (v1.0)  B & C       0.150    0.496     0.636     0.820
#                    Buoys     160.741  279.100   427.633   645.400
#                    C2K       195.077  402.600   632.267   850.800
#                    UCI       584.291  722.200  1450.217  2199.000
#  PSO-GRAANK (v1.0) B & C       0.166    0.294     0.549     0.928
#                    Buoys     195.548  157.200   486.583   871.500
#                    C2K       130.423  513.900   754.458   980.800
#                    UCI       783.593  617.100  2084.092  3325.000
#
#                             Pattern-count                      Memory         \
#                                       std   min    mean   max     std    min
# Algorithm          Data-set
#  ACO-GRAANK (v2.0) B & C            4.252   9.0  17.417  23.0   9.639   99.2
#                    Buoys            6.631  24.0  36.167  46.0  15.149  154.0
#                    C2K              6.092  16.0  25.750  34.0   1.303  199.0
#                    UCI              1.485   2.0   4.250   7.0  13.226  112.0
#  GA-GRAANK (v1.0)  B & C            2.066   1.0   3.333   7.0   2.140   94.7
#                    Buoys            0.816   1.0   2.333   3.0   2.366  113.0
#                    C2K              0.753   1.0   1.833   3.0   1.169  124.0
#                    UCI              0.408   1.0   1.167   2.0   1.643  103.0
#  PSO-GRAANK (v1.0) B & C            0.522   1.0   1.500   2.0   0.840   83.3
#                    Buoys            0.452   1.0   1.250   2.0   0.778  102.0
#                    C2K              0.492   1.0   1.333   2.0   1.193  112.0
#                    UCI              0.000   1.0   1.000   1.0   1.638   92.6
#
#
#                                 mean    max
# Algorithm          Data-set
#  ACO-GRAANK (v2.0) B & C     118.183  131.0
#                    Buoys     182.750  203.0
#                    C2K       200.333  202.0
#                    UCI       128.250  153.0
#  GA-GRAANK (v1.0)  B & C      97.467  101.0
#                    Buoys     116.000  119.0
#                    C2K       125.167  127.0
#                    UCI       105.500  108.0
#  PSO-GRAANK (v1.0) B & C      84.542   85.9
#                    Buoys     102.667  104.0
#                    C2K       113.833  116.0
#                    UCI        95.750   97.3

# %%
#df_gra1 = df_graank[['Data-set', 'Algorithm', 'Pattern-count', 'Run-time', 'Memory']]
#df_gra1 = df_gra1.groupby(["Algorithm", "Data-set"]).describe(percentiles=[])
#df_gra1

#df_aco1 = df_aco[['Data-set', 'Algorithm', 'Pattern-count', 'Max-iteration', 'Iterations', 'E-factor']]

#df = df_aco1.groupby(["Algorithm", "E-factor", "Data-set"]).describe()
#df2 = pd.concat([df.min(), df.mean(), df.max(), df.std()], keys=['min', 'mean', 'max', 'std'], axis=1)
#df2.filter(like="Run-time")
#df2.columns = df2.columns.swaplevel(0, 1)
#df2.sort_index(axis=1, level=0, inplace=True, ascending=False)
#df.round(3)

# %%
import matplotlib.pyplot as plt

data_sets = ['B & C', 'Buoys', 'C2K', 'UCI']
for ds in data_sets:
    df1 = df_aco.loc[df_aco['Data-set'] == ds]
    
    e_fs = [0.1, 0.3, 0.5, 0.7, 0.9]
    e_fs = [0.1, 0.3, 0.5]  # TO BE REMOVED
    
    for e in e_fs:
        df2 = df1.loc[df1['E-factor'] == e]
    
        fig = plt.figure(figsize=(40,5))
        #fig = plt.figure()
        #axes = fig.subplots(nrows=1, ncols=4)
        i = 1
        for index,row in df2.iterrows():
            # Results
            plt.subplot(1, 3, i)
            plt.plot(row['Iterations'])
            plt.semilogy(row['Iterations'])
            plt.xlim(0, row['Max-iteration'])
            plt.xlabel('Iterations')
            plt.ylabel('Best Cost')
            #plt.title('ACO, Dataset: ' + ds)
            plt.grid(True)
            i += 1

        fig.suptitle('Algorithm: ACO-GRAANK; E.factor: ' + str(e) + '; Dataset: ' + ds, fontsize=32)
        plt.show()

# %%
for ds in data_sets:
    df1 = df_ga.loc[df_ga['Data-set'] == ds]
    pcs = [0.1, 0.3, 0.5, 0.9]
    #pcs = [0.1, 0.3, 0.5]  # TO BE REMOVED
    
    for pc in pcs:
        df2 = df1.loc[df1['PC'] == pc]
    
        fig = plt.figure(figsize=(40,5))
        #fig = plt.figure()
        #axes = fig.subplots(nrows=1, ncols=4)
        i = 1
        for index,row in df2.iterrows():
            # Results
            plt.subplot(1, 3, i)
            plt.plot(row['Iterations'])
            plt.semilogy(row['Iterations'])
            plt.xlim(0, row['Max-iteration'])
            plt.xlabel('Iterations')
            plt.ylabel('Best Cost')
            #plt.title('ACO, Dataset: ' + ds)
            plt.grid(True)
            i += 1

        fig.suptitle('Algorithm: GA; Npop: ' + str(row['N-pop']) + '; PC: ' + str(pc) + '; Dataset: ' + ds, fontsize=32)
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Python/3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'N-pop'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-44fd34756c1c> in <module>
#      23             i += 1
#      24
# ---> 25         fig.suptitle('Algorithm: GA; Npop: ' + str(row['N-pop']) + '; PC: ' + str(pc) + '; Dataset: ' + ds, fontsize=32)
#      26         plt.show()
#
# /Library/Python/3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     849
#     850         elif key_is_scalar:
# --> 851             return self._get_value(key)
#     852
#     853         if is_hashable(key):
#
# /Library/Python/3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     957
#     958         # Similar to Index.get_value, but we do not fall back to positional
# --> 959         loc = self.index.get_loc(label)
#     960         return self.index._get_values_for_loc(self, loc, label)
#     961
#
# /Library/Python/3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'N-pop'

# %%
for ds in data_sets:
    df1 = df_pso.loc[df_pso['Data-set'] == ds]
    
    c2s = [0.1, 0.3, 0.5, 0.7, 0.9]
    # c2s = [0.1, 0.3]  # TO BE REMOVED
    
    for c2 in c2s:
        df2 = df1.loc[df1['C2'] == c2]
    
        fig = plt.figure(figsize=(40,5))
        #fig = plt.figure()
        #axes = fig.subplots(nrows=1, ncols=4)
        i = 1
        for index,row in df2.iterrows():
            # Results
            plt.subplot(1, 3, i)
            plt.plot(row['Iterations'])
            plt.semilogy(row['Iterations'])
            plt.xlim(0, row['Max-iteration'])
            plt.xlabel('Iterations')
            plt.ylabel('Best Position')
            #plt.title('ACO, Dataset: ' + ds)
            plt.grid(True)
            i += 1

        fig.suptitle('Algorithm: PSO; Nparticles: ' + str(row['N-particle']) + ';C1: ' + str(row['C1']) + ';C2: ' + str(row['C2']) + '; Dataset: ' + ds, fontsize=32)
        plt.show()

# %%
# Comparing Swarm vs Classical Algorithms

allpath = "./raw_files/14cores/"
allfiles = [f for f in listdir(allpath) if isfile(join(allpath, f))]

column_names = ['Data-set', 'Objects', 'Algorithm', 'Pattern-count', 'Run-time', 'Memory', 'E-factor', 'N-pop', 'N-particle', 'C1', 'C2']
df_all = pd.DataFrame(columns = column_names)


for file in allfiles:
    f_path = join(allpath, file)
    res = pd.read_csv(f_path, names=["A","B","C"], sep = ':', header=None, engine='python')
    run = float(res['B'][0][0:6]) # run-time
    mem = float(res['B'][1][0:5]) # memory
    alg = res['B'][2] # algorithm
    att = int(res['B'][3]) # number of attributes in the data set
    size = int(res['B'][4])  # data set size
    
    if att == 98:
        col = "C2K"
    elif att == 10:
        col = "B & C"
    elif att == 9:
        col = "UCI"
    elif att == 21:
        col = "Buoys"
    else:
        col = ""
    
    if alg == ' ACO-GRAANK (v4.0)':
        alg = ' ACO'
        evp = float(res['B'][5]) # evaporation factor
        sup = float(res['B'][6]) # minimum support
        pat = float(res['B'][8]) # patterns
        
        df_all = df_all.append({"Data-set": col, "Objects": size, "Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Pattern-count":pat, "E-factor": evp}, ignore_index=True)
    elif alg == ' GA-GRAANK (v1.0)':
        alg = ' GA'
        pop = float(res['B'][5]) # population size
        pc = float(res['B'][6]) # population size
        sup = float(res['B'][7]) # minimum support
        pat = float(res['B'][9]) # patterns  
        
        df_all = df_all.append({"Data-set": col, "Objects": size, "Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Pattern-count":pat, "N-pop": pop, "PC": pc}, ignore_index=True)
    elif alg == ' PSO-GRAANK (v1.0)':
        alg = ' PSO'
        vel = float(res['B'][5]) # velocity
        c1 = float(res['B'][6]) # personal coefficient
        c2 = float(res['B'][7]) # global coefficient
        npat = float(res['B'][8]) # particle count
        sup = float(res['B'][9]) # minimum support
        pat = float(res['B'][11]) # patterns
        
        df_all = df_all.append({"Data-set": col, "Objects": size, "Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Pattern-count":pat, "N-particle": npat, "Velocity": vel, "C1": c1, "C2": c2}, ignore_index=True)
    else:
        sup = float(res['B'][5]) # minimum support
        pat = float(res['B'][7]) # patterns

        df_all = df_all.append({"Data-set": col, "Objects": size, "Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Pattern-count":pat}, ignore_index=True)

df_all
# Out:
#    Data-set Objects         Algorithm  Pattern-count  Run-time  Memory  \
# 0       C2K    3943               ACO            8.0   459.500   274.0
# 1     Buoys   15402                GA            1.0   982.400   107.0
# 2       C2K    3943                GA            1.0   469.500   117.0
# 3       UCI   46774               PSO            1.0   965.500    88.1
# 4     B & C     116               PSO            1.0     0.066    75.7
# 5     B & C     116               ACO            5.0     0.083    95.0
# 6       C2K    3943                GA            1.0   472.200   117.0
# 7     B & C     116     ACO-LCM (1.0)           21.0     0.591   412.0
# 8     B & C     116           GRAANK            58.0     1.223    99.4
# 9     B & C     116   LCM-GRAD (1.0)            19.0    15.720  1044.0
# 10    Buoys   15402                GA            1.0   981.000   108.0
# 11    Buoys   15402               PSO            1.0   931.400    98.2
# 12    Buoys   15402                GA            1.0   998.300   105.0
# 13      C2K    3943           GRAANK           604.0   389.700   208.0
# 14      UCI   46774                GA            1.0  1142.000    99.3
# 15      UCI   46774                GA            1.0  1161.000    98.8
# 16    Buoys   15402               PSO            1.0   920.600    96.1
# 17      UCI   46774               ACO            1.0   660.300   120.0
# 18      C2K    3943               PSO            1.0   599.500   107.0
# 19    B & C     116               PSO            1.0     0.058    74.7
# 20    B & C     116                GA            1.0     0.078    86.5
# 21    B & C     116     ACO-LCM (1.0)            6.0     0.491   373.0
# 22      C2K    3943               PSO            1.0   457.000   107.0
# 23    Buoys   15402               ACO            7.0   899.100   134.0
# 24      UCI   46774               ACO            1.0   657.600   116.0
# 25      UCI   46774           GRAANK             4.0   386.900    63.2
# 26    Buoys   15402               ACO            6.0   891.100   130.0
# 27      C2K    3943           GRAANK           604.0   397.300   208.0
# 28    Buoys   15402               ACO           13.0   954.800   149.0
# 29      C2K    3943               ACO            5.0   582.500   241.0
# 30      UCI   46774           GRAANK             4.0   382.900    63.2
# 31      UCI   46774               PSO            1.0   933.200    86.6
# 32    B & C     116     ACO-LCM (1.0)           16.0     0.557   408.0
# 33    B & C     116               ACO            5.0     0.092    96.2
# 34      UCI   46774               PSO            1.0   972.800    88.1
# 35      UCI   46774               ACO            1.0   717.800   123.0
# 36      C2K    3943           GRAANK           604.0   413.500   208.0
# 37      UCI   46774                GA            1.0   927.800    98.8
# 38    Buoys   15402               PSO            1.0   766.400    95.4
# 39      C2K    3943               ACO            9.0   460.600   283.0
# 40    B & C     116               PSO            1.0     0.062    75.1
# 41    B & C     116                GA            1.0     0.075    87.0
# 42    B & C     116               ACO            4.0     0.074    92.8
# 43    B & C     116   LCM-GRAD (1.0)            19.0    15.880  1044.0
# 44      C2K    3943               PSO            1.0   458.700   107.0
# 45      C2K    3943                GA            1.0   465.600   118.0
# 46    B & C     116           GRAANK            58.0     1.212    99.4
# 47    B & C     116                GA            1.0     0.075    86.2
# 48      UCI   46774           GRAANK             4.0   474.600    63.2
# 49    B & C     116   LCM-GRAD (1.0)            19.0    15.820  1044.0
# 50    B & C     116           GRAANK            58.0     1.223    98.6
#
#     E-factor  N-pop  N-particle   C1   C2  Support   PC  Velocity
# 0        0.9    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 1        NaN   10.0         NaN  NaN  NaN      0.5  0.5       NaN
# 2        NaN   10.0         NaN  NaN  NaN      0.5  0.5       NaN
# 3        NaN    NaN         5.0  0.5  0.9      0.5  NaN       0.5
# 4        NaN    NaN         5.0  0.5  0.9      0.5  NaN       0.5
# 5        0.9    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 6        NaN   10.0         NaN  NaN  NaN      0.5  0.5       NaN
# 7        NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 8        NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 9        NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 10       NaN   10.0         NaN  NaN  NaN      0.5  0.5       NaN
# 11       NaN    NaN         5.0  0.5  0.9      0.5  NaN       0.5
# 12       NaN   10.0         NaN  NaN  NaN      0.5  0.5       NaN
# 13       NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 14       NaN   10.0         NaN  NaN  NaN      0.5  0.5       NaN
# 15       NaN   10.0         NaN  NaN  NaN      0.5  0.5       NaN
# 16       NaN    NaN         5.0  0.5  0.9      0.5  NaN       0.5
# 17       0.9    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 18       NaN    NaN         5.0  0.5  0.9      0.5  NaN       0.5
# 19       NaN    NaN         5.0  0.5  0.9      0.5  NaN       0.5
# 20       NaN   10.0         NaN  NaN  NaN      0.5  0.5       NaN
# 21       NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 22       NaN    NaN         5.0  0.5  0.9      0.5  NaN       0.5
# 23       0.9    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 24       0.9    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 25       NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 26       0.9    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 27       NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 28       0.9    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 29       0.9    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 30       NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 31       NaN    NaN         5.0  0.5  0.9      0.5  NaN       0.5
# 32       NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 33       0.9    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 34       NaN    NaN         5.0  0.5  0.9      0.5  NaN       0.5
# 35       0.9    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 36       NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 37       NaN   10.0         NaN  NaN  NaN      0.5  0.5       NaN
# 38       NaN    NaN         5.0  0.5  0.9      0.5  NaN       0.5
# 39       0.9    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 40       NaN    NaN         5.0  0.5  0.9      0.5  NaN       0.5
# 41       NaN   10.0         NaN  NaN  NaN      0.5  0.5       NaN
# 42       0.9    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 43       NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 44       NaN    NaN         5.0  0.5  0.9      0.5  NaN       0.5
# 45       NaN   10.0         NaN  NaN  NaN      0.5  0.5       NaN
# 46       NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 47       NaN   10.0         NaN  NaN  NaN      0.5  0.5       NaN
# 48       NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 49       NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN
# 50       NaN    NaN         NaN  NaN  NaN      0.5  NaN       NaN

# %%
# Only include these columns
df_all2 = df_all[['Data-set', 'Algorithm', 'Pattern-count', 'Run-time', 'Memory']]  #, 'E-factor', 'N-pop', 'N-particle', 'C1', 'C2']]


df = df_all2.groupby(["Data-set", "Algorithm"])#.describe(percentiles=[])
df2 = pd.concat([df.min(), df.mean(), df.max(), df.std()], keys=['min', 'mean', 'max', 'std'], axis=1)
#df2.filter(like="Run-time")
df2.columns = df2.columns.swaplevel(0, 1)
df2.sort_index(axis=1, level=0, inplace=True, ascending=False)
df2.round(3)
# Out:
#                           Run-time                              Pattern-count  \
#                                std      min      mean       max           std
# Data-set Algorithm
# B & C     ACO                0.009    0.074     0.083     0.092         0.577
#           ACO-LCM (1.0)      0.051    0.491     0.546     0.591         7.638
#           GA                 0.002    0.075     0.076     0.078         0.000
#           GRAANK             0.006    1.212     1.219     1.223         0.000
#           LCM-GRAD (1.0)     0.081   15.720    15.807    15.880         0.000
#           PSO                0.004    0.058     0.062     0.066         0.000
# Buoys     ACO               34.699  891.100   915.000   954.800         3.786
#           GA                 9.610  981.000   987.233   998.300         0.000
#           PSO               92.303  766.400   872.800   931.400         0.000
# C2K       ACO               70.699  459.500   500.867   582.500         2.082
#           GA                 3.318  465.600   469.100   472.200         0.000
#           GRAANK            12.156  389.700   400.167   413.500         0.000
#           PSO               81.786  457.000   505.067   599.500         0.000
# UCI       ACO               34.004  657.600   678.567   717.800         0.000
#           GA               129.502  927.800  1076.933  1161.000         0.000
#           GRAANK            51.827  382.900   414.800   474.600         0.000
#           PSO               21.074  933.200   957.167   972.800         0.000
#
#                                                   Memory                    \
#                              min     mean    max     std     min      mean
# Data-set Algorithm
# B & C     ACO                4.0    4.667    5.0   1.724    92.8    94.667
#           ACO-LCM (1.0)      6.0   14.333   21.0  21.455   373.0   397.667
#           GA                 1.0    1.000    1.0   0.404    86.2    86.567
#           GRAANK            58.0   58.000   58.0   0.462    98.6    99.133
#           LCM-GRAD (1.0)    19.0   19.000   19.0   0.000  1044.0  1044.000
#           PSO                1.0    1.000    1.0   0.503    74.7    75.167
# Buoys     ACO                6.0    8.667   13.0  10.017   130.0   137.667
#           GA                 1.0    1.000    1.0   1.528   105.0   106.667
#           PSO                1.0    1.000    1.0   1.457    95.4    96.567
# C2K       ACO                5.0    7.333    9.0  22.113   241.0   266.000
#           GA                 1.0    1.000    1.0   0.577   117.0   117.333
#           GRAANK           604.0  604.000  604.0   0.000   208.0   208.000
#           PSO                1.0    1.000    1.0   0.000   107.0   107.000
# UCI       ACO                1.0    1.000    1.0   3.512   116.0   119.667
#           GA                 1.0    1.000    1.0   0.289    98.8    98.967
#           GRAANK             4.0    4.000    4.0   0.000    63.2    63.200
#           PSO                1.0    1.000    1.0   0.866    86.6    87.600
#
#
#                               max
# Data-set Algorithm
# B & C     ACO                96.2
#           ACO-LCM (1.0)     412.0
#           GA                 87.0
#           GRAANK             99.4
#           LCM-GRAD (1.0)   1044.0
#           PSO                75.7
# Buoys     ACO               149.0
#           GA                108.0
#           PSO                98.2
# C2K       ACO               283.0
#           GA                118.0
#           GRAANK            208.0
#           PSO               107.0
# UCI       ACO               123.0
#           GA                 99.3
#           GRAANK             63.2
#           PSO                88.1
