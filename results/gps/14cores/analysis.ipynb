# %%
import pandas as pd
from os import listdir
from os.path import isfile, join

mypath = "./gps/14cores/all/"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
print(onlyfiles)
# Out:
# ['res_graank16106177765642927.txt', 'res_aco16106168656965058.txt', 'res_aco16106168099093857.txt', 'res_acolcm16106179018381035.txt', 'res_aco16106168394382548.txt', 'res_aco16106168354930751.txt', 'res_graank16106176588825037.txt', 'res_aco16106167471486.txt', 'res_lcm16106337771060407.txt', 'res_aco16106149240726366.txt', 'res_aco16106168900660162.txt', 'res_acolcm1610615075272825.txt', 'res_graank1610615045334179.txt', 'res_aco16106168720388532.txt', 'res_acolcm16106189164721868.txt', 'res_lcm16106235039754982.txt', 'res_graank1610617453250143.txt', 'res_graank16106173020997963.txt', 'res_lcm16106194997845368.txt', 'res_aco1610616866855852.txt', 'res_lcm16106155623733475.txt', 'res_acolcm16106184388649282.txt', 'res_acolcm16106183216229765.txt', 'res_graank1610617441403747.txt', 'res_aco16106168060724714.txt', 'res_graank1610617276960729.txt', 'res_lcm1610626835267798.txt', 'res_aco16106168193016458.txt', 'res_graank16106175675059605.txt', 'res_graank16106170997904348.txt', 'res_
# ...

# %%
file = onlyfiles[0]
f_path = join(mypath,file)
print(f_path)
# Out:
# ./gps/14cores/all/res_graank16106177765642927.txt

# %%
res = pd.read_csv(f_path, sep = ': ', header=None, engine='python', nrows=8)
res
# Out:
#                              0                           1
# 0                     Run-time  2.4176082611083984 seconds
# 1  Total allocated memory size                    44.3 KiB
# 2                    Algorithm                      GRAANK
# 3  No. of (dataset) attributes                          98
# 4      No. of (dataset) tuples                         200
# 5              Minimum support                         0.9
# 6              Number of cores                          14
# 7           Number of patterns                           0

# %%
column_names = ["Algorithm", "Support", "Run-time", "Memory", "Patterns"]

df_bc_5 = pd.DataFrame(columns = column_names)
df_bc_6 = pd.DataFrame(columns = column_names)
df_bc_7 = pd.DataFrame(columns = column_names)
df_bc_8 = pd.DataFrame(columns = column_names)
df_bc_9 = pd.DataFrame(columns = column_names)

df_buoys_5 = pd.DataFrame(columns = column_names)
df_buoys_6 = pd.DataFrame(columns = column_names)
df_buoys_7 = pd.DataFrame(columns = column_names)
df_buoys_8 = pd.DataFrame(columns = column_names)
df_buoys_9 = pd.DataFrame(columns = column_names)

df_c2k_5 = pd.DataFrame(columns = column_names)
df_c2k_6 = pd.DataFrame(columns = column_names)
df_c2k_7 = pd.DataFrame(columns = column_names)
df_c2k_8 = pd.DataFrame(columns = column_names)
df_c2k_9 = pd.DataFrame(columns = column_names)

df_uci_5 = pd.DataFrame(columns = column_names)
df_uci_6 = pd.DataFrame(columns = column_names)
df_uci_7 = pd.DataFrame(columns = column_names)
df_uci_8 = pd.DataFrame(columns = column_names)
df_uci_9 = pd.DataFrame(columns = column_names)


for file in onlyfiles:
    f_path = join(mypath,file)
    res = pd.read_csv(f_path, sep = ': ', header=None, engine='python', nrows=8)
    run = float(res[1][0][0:6]) # run-time
    mem = float(res[1][1][0:5]) # memory
    pat = int(res[1][7]) # patterns
    alg = res[1][2] # algorithm
    att = int(res[1][3]) # number of attributes in the data set
    sup = float(res[1][5]) # minimum support



    if att == 98:
        col = "C2K"
        if sup == 0.5:
            df_c2k_5 = df_c2k_5.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.6:
            df_c2k_6 = df_c2k_6.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.7:
            df_c2k_7 = df_c2k_7.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.8:
            df_c2k_8 = df_c2k_8.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.9:
            df_c2k_9 = df_c2k_9.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
    elif att == 10:
        col = "B_C"
        if sup == 0.5:
            df_bc_5 = df_bc_5.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.6:
            df_bc_6 = df_bc_6.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.7:
            df_bc_7 = df_bc_7.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.8:
            df_bc_8 = df_bc_8.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.9:
            df_bc_9 = df_bc_9.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
    elif att == 9:
        col = "UCI"
        if sup == 0.5:
            df_uci_5 = df_uci_5.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.6:
            df_uci_6 = df_uci_6.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.7:
            df_uci_7 = df_uci_7.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.8:
            df_uci_8 = df_uci_8.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.9:
            df_uci_9 = df_uci_9.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
    elif att == 21:
        col = "Buoys"
        if sup == 0.5:
            df_buoys_5 = df_buoys_5.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.6:
            df_buoys_6 = df_buoys_6.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.7:
            df_buoys_7 = df_buoys_7.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.8:
            df_buoys_8 = df_buoys_8.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)
        elif sup == 0.9:
            df_buoys_9 = df_buoys_9.append({"Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)

# %%
column_names = ["Data-set", "Algorithm", "Support", "Run-time", "Memory", "Patterns"]

df_res = pd.DataFrame(columns = column_names)


for file in onlyfiles:
    f_path = join(mypath,file)
    res = pd.read_csv(f_path, sep = ': ', header=None, engine='python', nrows=8)
    run = float(res[1][0][0:6]) # run-time
    mem = float(res[1][1][0:5]) # memory
    pat = float(res[1][7]) # patterns
    alg = res[1][2] # algorithm
    att = int(res[1][3]) # number of attributes in the data set
    sup = float(res[1][5]) # minimum support



    if att == 98:
        col = "C2K"
    elif att == 10:
        col = "B_C"
    elif att == 9:
        col = "UCI"
    elif att == 21:
        col = "Buoys"
    else:
        col = ""
            
    df_res = df_res.append({"Data-set": col, "Algorithm":alg, "Support": sup, "Run-time":run, "Memory":mem, "Patterns":pat}, ignore_index=True)

# %%
df_res
#df_res.sort_values(by = ["Data-set", "Support", "Algorithm"])
# Out:
#     Data-set         Algorithm  Support  Run-time   Memory  Patterns
# 0        C2K            GRAANK      0.9    2.4176     44.3       0.0
# 1        C2K  ACO-GRAANK (2.0)      0.9    8.0027    247.4       0.0
# 2        UCI  ACO-GRAANK (2.0)      0.8    0.1444    130.7       1.0
# 3        C2K     ACO-LCM (1.0)      0.9   21.0300    490.0     199.0
# 4      Buoys  ACO-GRAANK (2.0)      0.9    0.7316    263.0       0.0
# 5        C2K  ACO-GRAANK (2.0)      0.9   14.5730    247.3       0.0
# 6        C2K            GRAANK      0.9    2.4073     44.3       0.0
# 7        UCI  ACO-GRAANK (2.0)      0.5    0.0765    106.0       1.0
# 8      Buoys    LCM-GRAD (1.0)      0.8  130.4300  50920.0      32.0
# 9      Buoys  ACO-GRAANK (2.0)      0.9    1.1242    207.2       1.0
# 10       UCI  ACO-GRAANK (2.0)      0.9    0.1662    183.2       1.0
# 11       UCI     ACO-LCM (1.0)      0.6   22.4970   1235.0       2.0
# 12       UCI            GRAANK      0.5    0.3837     73.6       7.0
# ...

# %%
pd.options.display.max_rows = 700
pd.options.display.max_columns = 40

# df_res.describe()
# df_res.groupby(["Data-set", "Support", "Algorithm"]).describe().to_excel("results.xlsx", sheet_name="Stats")
df_res.groupby(["Data-set", "Support", "Algorithm"]).describe()
# Out:
#                                   Run-time                                   \
#                                      count        mean        std       min
# Data-set Support Algorithm
# B_C      0.5     ACO-GRAANK (2.0)      9.0    0.032778   0.012202    0.0165
#                  ACO-LCM (1.0)         9.0    0.497778   0.032289    0.4457
#                  GRAANK                9.0    1.186878   0.010285    1.1691
#                  LCM-GRAD (1.0)        9.0   15.181333   0.232908   14.8850
#          0.6     ACO-GRAANK (2.0)      9.0    0.037467   0.023610    0.0196
#                  ACO-LCM (1.0)         9.0    0.545578   0.068187    0.4305
#                  GRAANK                9.0    0.517489   0.001260    0.5157
#                  LCM-GRAD (1.0)        9.0   14.859556   0.173633   14.5900
#          0.7     ACO-GRAANK (2.0)      9.0    0.074667   0.038185    0.0172
#                  ACO-LCM (1.0)         9.0    0.609389   0.099067    0.4775
# ...
